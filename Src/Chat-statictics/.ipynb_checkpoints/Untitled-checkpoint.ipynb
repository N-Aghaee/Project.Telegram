# %%
import json
from collections import Counter
from hazm import

# %%
with open('../data/result.json') as f:
    data = json.load(f)

# %%
msg_iter = iter(data['messages'])

# %%
text_countent = ''

# %%
for msg in data['messages']:
    if type(msg['text']) is str:
        text_content +=f"{msg['text']}"

# %%
text_content = Normalizer.normalize(text_content)

# %%
tokens = word_tokenrise(text_content)

# %%
counter(tokens)

# %%
Counter(text_content.split()).most_common()
# Out:
# [('امتحان', 81),
#  ('و', 63),
#  ('رو', 54),
#  ('که', 54),
#  ('از', 51),
#  ('هم', 48),
#  ('درس', 36),
#  ('استاد', 36),
#  ('من', 33),
#  ('دوتا', 30),
#  ('ساعت', 30),
#  ('ها', 30),
#  ('تو', 27),
#  ('ی', 27),
#  ('روز', 27),
#  ('سوال', 27),
#  ('باید', 27),
#  ('این', 24),
#  ('شما', 24),
#  ('۱۱', 24),
#  ('به', 24),
#  ('تا', 21),
#  ('هر', 21),
#  ('طبق', 21),
#  ('یه', 21),
#  ('هست', 18),
#  ('گروه', 18),
#  ('سیستم', 18),
#  ('عامل', 18),
#  ('دکتر', 18),
#  ('گندمی', 18),
#  ('جزوه', 15),
#  ('دست', 15),
#  ('ک', 15),
#  ('امتحانات', 15),
#  ('برای', 15),
#  ('می', 15),
#  ('تیر', 15),
#  ('دو', 15),
#  ('میشه', 15),
#  ('عمادی', 15),
#  ('با', 15),
#  ('دیگه', 15),
#  ('۲', 15),
#  ('ب', 12),
#  ('جلسه', 12),
#  ('اطلاع', 12),
#  ('در', 12),
#  ('طرح', 12),
#  ('شد', 12),
#  ('یکی', 12),
#  ('را', 12),
#  ('۴', 12),
#  ('همون', 12),
#  ('ولی', 12),
#  ('همه', 12),
#  ('برگه', 12),
#  ('Fit', 12),
#  ('کسی', 9),
#  ('حل', 9),
#  ('داشته', 9),
#  ('امروز', 9),
#  ('دایره', 9),
#  ('تاریخ', 9),
#  ('ابلاغ', 9),
#  ('۵', 9),
#  ('نوع', 9),
#  ('نیست', 9),
#  ('رسانی', 9),
#  ('کنید', 9),
#  ('کارت', 9),
#  ('ورود', 9),
#  ('تخصصی', 9),
#  ('نمیشه', 9),
#  ('اینکه', 9),
#  ('قرار', 9),
#  ('منم', 9),
#  ('آمادگی', 9),
#  ('بود', 9),
#  ('۱۱م', 9),
#  ('بگین', 9),
#  ('کدوم', 9),
#  ('اون', 9),
#  ('جواب', 9),
#  ('کتاب', 9),
#  ('های', 9),
#  ('فردا', 9),
#  ('قاب', 9),
#  ('مثال', 9),
#  ('خودم', 6),
#  ('چون', 6),
#  ('نویسی', 6),
#  ('زیادی', 6),
#  ('چنتا', 6),
#  ('دوستان', 6),
#  ('بار', 6),
#  ('کردم', 6),
#  ('اگه', 6),
#  ('فقط', 6),
#  ('ممنون', 6),
#  ('کرد', 6),
#  ('کس', 6),
#  ('یعنی', 6),
#  ('گروهی', 6),
#  ('داخل', 6),
#  ('ای', 6),
#  ('الان', 6),
#  ('بعد', 6),
#  ('راهرو', 6),
#  ('شماره', 6),
#  ('صندلی', 6),
#  ('کاری', 6),
#  ('بدن', 6),
#  ('دادم', 6),
#  ('۵ام', 6),
#  ('باشه', 6),
#  ('گفتن', 6),
#  ('مثل', 6),
#  ('گذاشتن', 6),
#  ('ندارم', 6),
#  ('ترم', 6),
#  ('ت', 6),
#  ('چرا', 6),
#  ('یک', 6),
#  ('همین', 6),
#  ('برا', 6),
#  ('ازیت', 6),
#  ('یازدهم', 6),
#  ('بدیم', 6),
#  ('صب', 6),
#  ('۶', 6),
#  ('فعلا', 6),
#  ('باشید', 6),
#  ('چی', 6),
#  ('ما', 6),
#  ('واسه', 6),
#  ('ام', 6),
#  ('خدا', 6),
#  ('بهتون', 6),
#  ('نفر', 6),
#  ('داشتیم', 6),
#  ('دارم', 6),
#  ('بچه', 6),
#  ('بگیرم', 6),
#  ('خودتون', 6),
#  ('داریم', 6),
#  ('راحت', 6),
#  ('بخواد', 6),
#  ('صفحه', 6),
#  ('داره', 6),
#  ('صد', 6),
#  ('داد', 6),
#  ('بشه', 6),
#  ('قطعه', 6),
#  ('قابمون', 6),
#  ('عدد', 6),
#  ('1', 6),
#  ('15', 6),
#  ('سلام', 4),
#  ('اش', 3),
#  ('کامل', 3),
#  ('بفرسته', 3),
#  ('لطفا..سیستم', 3),
#  ('عاملسلام', 3),
#  ('نویس', 3),
#  ('نوشتاری', 3),
#  ('داشت', 3),
#  ('جزوشو', 3),
#  ('خواستن', 3),
#  ('اسکن', 3),
#  ('کل', 3),
#  ('جزوش', 3),
#  ('ناقصه', 3),
#  ('بتونه', 3),
#  ('تکمیل\u200cکنه', 3),
#  ('روی', 3),
#  ('تمرینات', 3),
#  ('استناد', 3),
#  ('نکنن', 3),
#  ('مخصوصا', 3),
#  ('تمرینای', 3),
#  ('اخرین', 3),
#  ('موفق', 3),
#  ('باشید🤍Damet', 3),
#  ('garm🫂تشکر', 3),
#  ('آقای', 3),
#  ('زارع😂مرسی', 3),
#  ('دادین🌹خیلی', 3),
#  ('❤️', 3),
#  ('انشالله', 3),
#  ('هوامون', 3),
#  ('باشینسلام', 3),
#  ('اعلام', 3),
#  ('موجود', 3),
#  ('امتحاناتش', 3),
#  ('آزمون', 3),
#  ('شرکت', 3),
#  ('کند.', 3),
#  ('پاسخنامه', 3),
#  ('افراد', 3),
#  ('همان', 3),
#  ('صادر', 3),
#  ('شود.', 3),
#  ('تیرماه.یعنی', 3),
#  ('خواهد', 3),
#  ('تیر.🥺زحمتتون', 3),
#  ('استاد💔اگه', 3),
#  ('می\u200cشناسید', 3),
#  ('حتما', 3),
#  ('ندهد.چاره', 3),
#  ('دیگه😉🥲❤️چشماستاد', 3),
#  ('ساعته!', 3),
#  ('طراحی', 3),
#  ('زبان', 3),
#  ('برنامه', 3),
#  ('۱۴', 3),
#  ('هستن', 3),
#  ('موضوع', 3),
#  ('انصافه', 3),
#  ('قرون', 3),
#  ('اخر', 3),
#  ('پرداخت', 3),
#  ('بدهی', 3),
#  ('زمان', 3),
#  ('باشه؟استاد', 3),
#  ('باورکنید', 3),
#  ('۱', 3),
#  ('باشیم', 3),
#  ('۲۷', 3),
#  ('۵۴', 3),
#  ('حداقل', 3),
#  ('میتونن', 3),
#  ('برامون', 3),
#  ('انجام', 3),
#  ('تغییر', 3),
#  ('ساعتشه!راست', 3),
#  ('میگه', 3),
#  ('گربه', 3),
#  ('شرودینگر', 3),
#  ('نیستمن', 3),
#  ('پیام', 3),
#  ('ک\u200cاگ', 3),
#  ('امتحانتون', 3),
#  ('هست😂🤦🏼\u200d♀️توی', 3),
#  ('کانال', 3),
#  ('کانالو', 3),
#  ('نمیدونمبا', 3),
#  ('نکته', 3),
#  ('خیلی', 3),
#  ('مهم', 3),
#  ('رابطه', 3),
#  ('دانشجویانی', 3),
#  ('دارند', 3),
#  ('👇👇', 3),
#  ('پایان', 3),
#  ('آقایی', 3),
#  ('گروه،', 3),
#  ('5', 3),
#  ('تیرماه', 3),
#  ('14', 3),
#  ('هست.', 3),
#  ('آرزوی', 3),
#  ('موفقیتبله', 3),
#  ('اینو', 3),
#  ('اقایی', 3),
#  ('میگن', 3),
#  ('پیامشون', 3),
#  ('داده', 3),
#  ('ثبت', 3),
#  ('شده', 3),
#  ('بدنچطور', 3),
#  ('باهم', 3),
#  ('داد؟؟؟عزیزم', 3),
#  ('ذهنت', 3),
#  ('اذیت', 3),
#  ('کنی', 3),
#  ('بازه', 3),
#  ('امتحانات.', 3),
#  ('اول', 3),
#  ('هماهنگ', 3),
#  ('کردیم', 3),
#  ('بیان', 3),
#  ('جور\u200c', 3),
#  ('بهم', 3),
#  ('خبر', 3),
#  ('دادن', 3),
#  ('مشخصه', 3),
#  ('خودش', 3),
#  ('گیرن.این', 3),
#  ('کنم', 3),
#  ('تون', 3),
#  ('میدین😉استاد', 3),
#  ('ذهن', 3),
#  ('نشه', 3),
#  ('رحمی', 3),
#  ('بکند', 3),
#  ('سوالا', 3),
#  ('بگد', 3),
#  ('چیا', 3),
#  ('هه', 3),
#  ('نشیماستاد', 3),
#  ('اکثر', 3),
#  ('دانشجو', 3),
#  ('سیما', 3),
#  ('دارناستاد', 3),
#  ('ماهم', 3),
#  ('بنظرتون', 3),
#  ('توان', 3),
#  ('دقت', 3),
#  ('میتونیم', 3),
#  ('بزاریم', 3),
#  ('امتحان؟منم', 3),
#  ('همینههمه', 3),
#  ('ساعتی', 3),
#  ('همینن', 3),
#  ('اینکهمن', 3),
#  ('جدا', 3),
#  ('۸', 3),
#  ('ارم', 3),
#  ('عصربله', 3),
#  ('انصافه😂سلام', 3),
#  ('بخونید', 3),
#  ('ببینیم', 3),
#  ('میشه.استاد', 3),
#  ('بین', 3),
#  ('بیاییم', 3),
#  ('خودتونه', 3),
#  ('ماشاالله...سلام', 3),
#  ('اه', 3),
#  ('گل', 3),
#  ('چیز.الان', 3),
#  ('تکلیف', 3),
#  ('چیع۵م', 3),
#  ('بیایم', 3),
#  ('بیایمنیایمفعلا', 3),
#  ('نظر', 3),
#  ('بیایید.', 3),
#  ('ابلاغ.', 3),
#  ('دونه', 3),
#  ('چقدر', 3),
#  ('دری', 3),
#  ('زدیم.بازم', 3),
#  ('تونستیم', 3),
#  ('کنیم', 3),
#  ('سریع', 3),
#  ('میگیم', 3),
#  ('اونهایی', 3),
#  ('خوان', 3),
#  ('بیان.', 3),
#  ('بیایید.یعنی', 3),
#  ('۳۳', 3),
#  ('هستید', 3),
#  ('ماه.اگر', 3),
#  ('چهارتا', 3),
#  ('مسئول', 3),
#  ('مث', 3),
#  ('استاااد', 3),
#  ('بازم', 3),
#  ('استاد❤️سلام', 3),
#  ('۱۱ام', 3),
#  ('چکارکنم', 3),
#  ('نمی', 3),
#  ('تونم', 3),
#  ('بدیمبله', 3),
#  ('تداخل', 3),
#  ('دارند.اول', 3),
#  ('بیایید', 3),
#  ('سرجلسه', 3),
#  ('مراقب', 3),
#  ('دارید.', 3),
#  ('دادین', 3),
#  ('دوم', 3),
#  ('میدن.', 3),
#  ('حوزه', 3),
#  ('نباید', 3),
#  ('بیرون', 3),
#  ('برینچون', 3),
#  ('منتظر', 3),
#  ('باشم', 3),
#  ('برگردم', 3),
#  ('میبدباید', 3),
#  ('برید', 3),
#  ('بخش', 3),
#  ('برگزاری', 3),
#  ('فرمشو', 3),
#  ('پر', 3),
#  ('کنیداستاد', 3),
#  ('احتمالا', 3),
#  ('ابتدا', 3),
#  ('شمارو', 3),
#  ('بگیریمامتحان', 3),
#  ('ساعتش', 3),
#  ('هستفرقی', 3),
#  ('نداره', 3),
#  ('انتخاب', 3),
#  ('میکنید', 3),
#  ('سر', 3),
#  ('امتحام', 3),
#  ('بشینید', 3),
#  ('بردتون', 3),
#  ('بیارنامتحان', 3),
#  ('۷۰', 3),
#  ('دقیقه', 3),
#  ('وقت', 3),
#  ('دارهاستاد', 3),
#  ('تورک', 3),
#  ('امتحانو', 3),
#  ('بگیریداستاد', 3),
#  ('دوتا\u200cامتحان', 3),
#  ('سنگین', 3),
#  ('سوالامن', 3),
#  ('تاش', 3),
#  ('تخصصیهب', 3),
#  ('نظرم', 3),
#  ('لف', 3),
#  ('بدهسوال', 3),
#  ('سخت', 3),
#  ('نیست.', 3),
#  ('ساعته', 3),
#  ('میدین.۸', 3),
#  ('یکیشه', 3),
#  ('عصرم', 3),
#  ('امتحانسوال', 3),
#  ('تحویل', 3),
#  ('چند', 3),
#  ('پیشخیلی', 3),
#  ('سختهاستاد', 3),
#  ('تعریفیارو', 3),
#  ('مسائلش', 3),
#  ('خودمونخدا', 3),
#  ('تاشو', 3),
#  ('میوفتم😄تعریف', 3),
#  ('دادمو', 3),
#  ('مابقی', 3),
#  ('کلاس', 3),
#  ('دادمخوب', 3),
#  ('شد؟؟؟؟؟؟چ', 3),
#  ('اخرمه', 3),
#  ('استاد🥹والا', 3),
#  ('نمیدونم😄😄استاد', 3),
#  ('۲۰', 3),
#  ('نمیصرفه', 3),
#  ('خداییشاستاد', 3),
#  ('چ', 3),
#  ('فصلی🫣اینم', 3),
#  ('حرفیه👌شب', 3),
#  ('خیرررررررحداقل', 3),
#  ('فصلشو', 3),
#  ('یا', 3),
#  ('مبحثشو', 3),
#  ('استاااداستاد', 3),
#  ('جزومو', 3),
#  ('گم', 3),
#  ('کردم😐چ', 3),
#  ('غلطی', 3),
#  ('بکنمسلام', 3),
#  ('پیگیری', 3),
#  ('هماهنگی', 3),
#  ('هایی', 3),
#  ('کردند', 3),
#  ('اصرار', 3),
#  ('مکرر', 3),
#  ('مون', 3),
#  ('بر', 3),
#  ('بیاد', 3),
#  ('بده.', 3),
#  ('هستم', 3),
#  ('حوزه.استاد', 3),
#  ('میخوام', 3),
#  ('بیام', 3),
#  ('یهو', 3),
#  ('نیام', 3),
#  ('هیشکی', 3),
#  ('نباشه🥺💔۱۱م', 3),
#  ('دیگه؟ای', 3),
#  ('شما😅استاد', 3),
#  ('2', 3),
#  ('؟😁🥲بله.', 3),
#  ('متفاوت', 3),
#  ('شدهبلهمرسی', 3),
#  ('خسته', 3),
#  ('نباشید❤️استاد', 3),
#  ('زحمت', 3),
#  ('دادین😂', 3),
#  ('سوالاشم', 3),
#  ('نمیخوندیمدمتون', 3),
#  ('گرم', 3),
#  ('بازمممنون', 3),
#  ('استاد😍❤️میترسم', 3),
#  ('دوبار', 3),
#  ('اشتباه', 3),
#  ('بنویسید😉😄😂از', 3),
#  ('بعید', 3),
#  ('😂😂❤️', 3),
#  ('دمتون', 3),
#  ('گرماستاد', 3),
#  ('تمرکز', 3),
#  ('گذاشتیم', 3),
#  ('بعدی', 3),
#  ('ایشالله', 3),
#  ('هماینقدر', 3),
#  ('چونه', 3),
#  ('زدید', 3),
#  ('حالا', 3),
#  ('میگی', 3),
#  ('میایی؟😄استاد', 3),
#  ('حفظیا', 3),
#  ('مسئله', 3),
#  ('کلا', 3),
#  ('تستیه؟همه', 3),
#  ('تشریحیهاستاد', 3),
#  ('سوم', 3),
#  ('امید', 3),
#  ('داشتم', 3),
#  ('نشد', 3),
#  ('نخوندم😔😐اوکی', 3),
#  ('ممنون❤️انشالله', 3),
#  ('یازدهمفرق', 3),
#  ('lru', 3),
#  ('fifo', 3),
#  ('میگهمرسیممنون', 3),
#  ('توجهتون😕هرکس', 3),
#  ('بالایی', 3),
#  ('عیب', 3),
#  ('بندی', 3),
#  ('بگه', 3),
#  ('بطور', 3),
#  ('خلاصهالگوریتم', 3),
#  ('LRU', 3),
#  ('وقتی', 3),
#  ('عددی', 3),
#  ('وارد', 3),
#  ('هامون', 3),
#  ('قبل', 3),
#  ('وجود', 3),
#  ('،', 3),
#  ('بالا', 3),
#  ('میاد', 3),
#  ('میگیره', 3),
#  ('Fifo', 3),
#  ('عددای', 3),
#  ('توی', 3),
#  ('عینا', 3),
#  ('تکرار', 3),
#  ('نمیادپارگی', 3),
#  ('خارجی', 3),
#  (':', 3),
#  ('فضا', 3),
#  ('خالی', 3),
#  ('کوچک', 3),
#  ('اما', 3),
#  ('نمیتونیم', 3),
#  ('بزرگ', 3),
#  ('حافظه', 3),
#  ('بیاریمخیلی', 3),
#  ('ممنوناستاد', 3),
#  ('دیه', 3),
#  ('بیاین', 3),
#  ('مثالارو', 3),
#  ('هیچ', 3),
#  ('ذهنیتی', 3),
#  ('مثالو', 3),
#  ('چجوری', 3),
#  ('بدست', 3),
#  ('اوردم', 3),
#  ('بیشتر', 3),
#  ('خوندن', 3),
#  ('استدلال', 3),
#  ('میکنمکدوم', 3),
#  ('مشکل', 3),
#  ('دارین', 3),
#  ('؟!؟شما', 3),
#  ('میتونید', 3),
#  ('بزنین', 3),
#  ('لطفا؟؟😐😐', 3),
#  ('الگوریتم', 3),
#  ('.', 3),
#  ('؟!!!؟', 3),
#  ('😐😐😐🙄15', 3),
#  ('تا😂1.FCFS', 3),
#  ('2.SJF', 3),
#  ('3.RR', 3),
#  ('4.SRT', 3),
#  ('5.Priority', 3),
#  ('6.MFQ', 3),
#  ('7.LPT', 3),
#  ('8.Lottery', 3),
#  ('1.First', 3),
#  ('2.Next', 3),
#  ('3.Best', 3),
#  ('4.Worst', 3),
#  ('1.FIFO', 3),
#  ('2.LRU', 3),
#  ('3.Optimal😢زیاد', 3),
#  ('اخوی', 3),
#  ('اینطور', 3),
#  ('گفتی', 3),
#  ('حس', 3),
#  ('میکنم', 3),
#  ('هیچی', 3),
#  ('بلد', 3),
#  ('نیستم', 3),
#  ('استرس', 3),
#  ('نده😐سلام', 2),
#  ('نده😐', 1)]
